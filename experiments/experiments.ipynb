# %%
import os
from pymongo import MongoClient

os.environ['PYMONGO_DNS_RESOLVER'] = '8.8.8.8'

uri = "mongodb+srv://kartiknimhan9929:Wf0uzmURKyeU3WtX@cluster0.n7um431.mongodb.net/?retryWrites=true&w=majority"

try:
    client = MongoClient(uri, serverSelectionTimeoutMS=5000)
    client.server_info()  # Trigger a server selection to force a connection check.
    print("Connection successful!")
except Exception as e:
    print("An error occurred:", e)
# Out:
# An error occurred: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
database=client["youtubecommunity"]

# %%
Wf0uzmURKyeU3WtX

# %%
collection=database["session"]

# %%
data={

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
}

# %%
data
# Out:
# {'coursename': 'genai', 'instrutorname': 'sunny', 'modeofsession': 'english'}

# %%
collection.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 collection.insert_one(data)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:864, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     860     document["_id"] = ObjectId()  # type: ignore[index]
#     862 write_concern = self._write_concern_for(session)
#     863 return InsertOneResult(
# --> 864     self._insert_one(
#     865         document,
#     866         ordered=True,
#     867         write_concern=write_concern,
#     868         op_id=None,
#     869         bypass_doc_val=bypass_document_validation,
#     870         session=session,
#     871         comment=comment,
#     872     ),
#     873     write_concern.acknowledged,
#     874 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:804, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     792     result = conn.command(
#     793         self._database.name,
#     794         command,
#    (...)
#     799         retryable_write=retryable_write,
#     800     )
#     802     _check_write_command_response(result)
# --> 804 self._database.client._retryable_write(
#     805     acknowledged, _insert_command, session, operation=_Op.INSERT
#     806 )
#     808 if not isinstance(doc, RawBSONDocument):
#     809     return doc.get("_id")
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1848, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1834 """Execute an operation with consecutive retries if possible
#    1835
#    1836 Returns func()'s return value on success. On error retries the same
#    (...)
#    1845 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1846 """
#    1847 with self._tmp_session(session) as s:
# -> 1848     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1734, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1729 # Ensure that the options supports retry_writes and there is a valid session not in
#    1730 # transaction, otherwise, we will not support retry behavior for this txn.
#    1731 retryable = bool(
#    1732     retryable and self.options.retry_writes and session and not session.in_transaction
#    1733 )
# -> 1734 return self._retry_internal(
#    1735     func=func,
#    1736     session=session,
#    1737     bulk=bulk,
#    1738     operation=operation,
#    1739     retryable=retryable,
#    1740     operation_id=operation_id,
#    1741 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1780, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1743 @_csot.apply
#    1744 def _retry_internal(
#    1745     self,
#    (...)
#    1754     operation_id: Optional[int] = None,
#    1755 ) -> T:
#    1756     """Internal retryable helper for all client transactions.
#    1757
#    1758     :param func: Callback function we want to retry
#    (...)
#    1767     :return: Output of the calling func()
#    1768     """
#    1769     return _ClientConnectionRetryable(
#    1770         mongo_client=self,
#    1771         func=func,
#    1772         bulk=bulk,
#    1773         operation=operation,
#    1774         is_read=is_read,
#    1775         session=session,
#    1776         read_pref=read_pref,
#    1777         address=address,
#    1778         retryable=retryable,
#    1779         operation_id=operation_id,
# -> 1780     ).run()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2367, in _ClientConnectionRetryable.run(self)
#    2365 self._check_last_error(check_csot=True)
#    2366 try:
# -> 2367     return self._read() if self._is_read else self._write()
#    2368 except ServerSelectionTimeoutError:
#    2369     # The application may think the write was never attempted
#    2370     # if we raise ServerSelectionTimeoutError on the retry
#    2371     # attempt. Raise the original exception instead.
#    2372     self._check_last_error()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2471, in _ClientConnectionRetryable._write(self)
#    2469 is_mongos = False
#    2470 self._server = self._get_server()
# -> 2471 with self._client._checkout(self._server, self._session) as conn:
#    2472     max_wire_version = conn.max_wire_version
#    2473     sessions_supported = (
#    2474         self._session
#    2475         and self._server.description.retryable_writes_supported
#    2476         and conn.supports_sessions
#    2477     )
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1543, in MongoClient._checkout(self, server, session)
#    1541     yield session._pinned_connection
#    1542     return
# -> 1543 with server.checkout(handler=err_handler) as conn:
#    1544     # Pin this session to the selected server or connection.
#    1545     if (
#    1546         in_txn
#    1547         and session
#    (...)
#    1552         )
#    1553     ):
#    1554         session._pin(server, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1335, in Pool.checkout(self, handler)
#    1326 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1327     _debug_log(
#    1328         _CONNECTION_LOGGER,
#    1329         clientId=self._client_id,
#    (...)
#    1332         serverPort=self.address[1],
#    1333     )
# -> 1335 conn = self._get_conn(checkout_started_time, handler=handler)
#    1337 duration = time.monotonic() - checkout_started_time
#    1338 if self.enabled_for_cmap:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1494, in Pool._get_conn(self, checkout_started_time, handler)
#    1492 else:  # We need to create a new connection
#    1493     try:
# -> 1494         conn = self.connect(handler=handler)
#    1495     finally:
#    1496         with self._max_connecting_cond:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1295, in Pool.connect(self, handler)
#    1292     if handler:
#    1293         handler.contribute_socket(conn, completed_handshake=False)
# -> 1295     conn.authenticate()
#    1296 except BaseException:
#    1297     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:648, in Connection.authenticate(self, reauthenticate)
#     645 if creds:
#     646     from pymongo.synchronous import auth
# --> 648     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     649 self.ready = True
#     650 duration = time.monotonic() - self.creation_time
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:452, in authenticate(credentials, conn, reauthenticate)
#     450     _authenticate_oidc(credentials, conn, reauthenticate)
#     451 else:
# --> 452     auth_func(credentials, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:356, in _authenticate_default(credentials, conn)
#     354         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     355     else:
# --> 356         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     357 else:
#     358     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:134, in _authenticate_scram(credentials, conn, mechanism)
#     127 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     129 cmd = {
#     130     "saslContinue": 1,
#     131     "conversationId": res["conversationId"],
#     132     "payload": Binary(client_final),
#     133 }
# --> 134 res = conn.command(source, cmd)
#     136 parsed = _parse_scram_response(res["payload"])
#     137 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
all_record=collection.find()

# %%
for record in all_record:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for record in all_record:
#       2     print(record)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1262, in Cursor.__next__(self)
#    1261 def __next__(self) -> _DocumentType:
# -> 1262     return self.next()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1256, in Cursor.next(self)
#    1254 if self._empty:
#    1255     raise StopIteration
# -> 1256 if len(self._data) or self._refresh():
#    1257     return self._data.popleft()
#    1258 else:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1204, in Cursor._refresh(self)
#    1182         raise InvalidOperation(
#    1183             "Passing a 'hint' is required when using the min/max query"
#    1184             " option to ensure the query utilizes the correct index"
#    1185         )
#    1186     q = self._query_class(
#    1187         self._query_flags,
#    1188         self._collection.database.name,
#    (...)
#    1202         self._exhaust,
#    1203     )
# -> 1204     self._send_message(q)
#    1205 elif self._id:  # Get More
#    1206     if self._limit:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\cursor.py:1099, in Cursor._send_message(self, operation)
#    1096     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1098 try:
# -> 1099     response = client._run_operation(
#    1100         operation, self._unpack_response, address=self._address
#    1101     )
#    1102 except OperationFailure as exc:
#    1103     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1104         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1704, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1694     operation.reset()  # Reset op in case of retry.
#    1695     return server.run_operation(
#    1696         conn,
#    1697         operation,
#    (...)
#    1701         self,
#    1702     )
# -> 1704 return self._retryable_read(
#    1705     _cmd,
#    1706     operation.read_preference,
#    1707     operation.session,  # type: ignore[arg-type]
#    1708     address=address,
#    1709     retryable=isinstance(operation, _Query),
#    1710     operation=operation.name,
#    1711 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1813, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1808 # Ensure that the client supports retrying on reads and there is no session in
#    1809 # transaction, otherwise, we will not support retry behavior for this call.
#    1810 retryable = bool(
#    1811     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1812 )
# -> 1813 return self._retry_internal(
#    1814     func,
#    1815     session,
#    1816     None,
#    1817     operation,
#    1818     is_read=True,
#    1819     address=address,
#    1820     read_pref=read_pref,
#    1821     retryable=retryable,
#    1822     operation_id=operation_id,
#    1823 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1780, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1743 @_csot.apply
#    1744 def _retry_internal(
#    1745     self,
#    (...)
#    1754     operation_id: Optional[int] = None,
#    1755 ) -> T:
#    1756     """Internal retryable helper for all client transactions.
#    1757
#    1758     :param func: Callback function we want to retry
#    (...)
#    1767     :return: Output of the calling func()
#    1768     """
#    1769     return _ClientConnectionRetryable(
#    1770         mongo_client=self,
#    1771         func=func,
#    1772         bulk=bulk,
#    1773         operation=operation,
#    1774         is_read=is_read,
#    1775         session=session,
#    1776         read_pref=read_pref,
#    1777         address=address,
#    1778         retryable=retryable,
#    1779         operation_id=operation_id,
# -> 1780     ).run()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2367, in _ClientConnectionRetryable.run(self)
#    2365 self._check_last_error(check_csot=True)
#    2366 try:
# -> 2367     return self._read() if self._is_read else self._write()
#    2368 except ServerSelectionTimeoutError:
#    2369     # The application may think the write was never attempted
#    2370     # if we raise ServerSelectionTimeoutError on the retry
#    2371     # attempt. Raise the original exception instead.
#    2372     self._check_last_error()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2499, in _ClientConnectionRetryable._read(self)
#    2497 self._server = self._get_server()
#    2498 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2499 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2500     conn,
#    2501     read_pref,
#    2502 ):
#    2503     if self._retrying and not self._retryable:
#    2504         self._check_last_error()
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1633, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1624 # Get a connection for a server matching the read preference, and yield
#    1625 # conn with the effective read preference. The Server Selection
#    1626 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1630 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1631 # to call _get_topology() again.
#    1632 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1633 with self._checkout(server, session) as conn:
#    1634     if single:
#    1635         if conn.is_repl and not (session and session.in_transaction):
#    1636             # Use primary preferred to ensure any repl set member
#    1637             # can handle the request.
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1543, in MongoClient._checkout(self, server, session)
#    1541     yield session._pinned_connection
#    1542     return
# -> 1543 with server.checkout(handler=err_handler) as conn:
#    1544     # Pin this session to the selected server or connection.
#    1545     if (
#    1546         in_txn
#    1547         and session
#    (...)
#    1552         )
#    1553     ):
#    1554         session._pin(server, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1335, in Pool.checkout(self, handler)
#    1326 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1327     _debug_log(
#    1328         _CONNECTION_LOGGER,
#    1329         clientId=self._client_id,
#    (...)
#    1332         serverPort=self.address[1],
#    1333     )
# -> 1335 conn = self._get_conn(checkout_started_time, handler=handler)
#    1337 duration = time.monotonic() - checkout_started_time
#    1338 if self.enabled_for_cmap:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1494, in Pool._get_conn(self, checkout_started_time, handler)
#    1492 else:  # We need to create a new connection
#    1493     try:
# -> 1494         conn = self.connect(handler=handler)
#    1495     finally:
#    1496         with self._max_connecting_cond:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1295, in Pool.connect(self, handler)
#    1292     if handler:
#    1293         handler.contribute_socket(conn, completed_handshake=False)
# -> 1295     conn.authenticate()
#    1296 except BaseException:
#    1297     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:648, in Connection.authenticate(self, reauthenticate)
#     645 if creds:
#     646     from pymongo.synchronous import auth
# --> 648     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     649 self.ready = True
#     650 duration = time.monotonic() - self.creation_time
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:452, in authenticate(credentials, conn, reauthenticate)
#     450     _authenticate_oidc(credentials, conn, reauthenticate)
#     451 else:
# --> 452     auth_func(credentials, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:356, in _authenticate_default(credentials, conn)
#     354         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     355     else:
# --> 356         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     357 else:
#     358     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:134, in _authenticate_scram(credentials, conn, mechanism)
#     127 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     129 cmd = {
#     130     "saslContinue": 1,
#     131     "conversationId": res["conversationId"],
#     132     "payload": Binary(client_final),
#     133 }
# --> 134 res = conn.command(source, cmd)
#     136 parsed = _parse_scram_response(res["payload"])
#     137 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
collection.insert_many(
    [
        {

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
},

{

    "coursename":"mlops",
    "instrutorname":"sunnysavita",
    "modeofsession":"english&hindi"
}
        
    ]
)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 collection.insert_many(
#       2     [
#       3         {
#       4
#       5     "coursename":"genai",
#       6     "instrutorname":"sunny",
#       7     "modeofsession":"english"
#       8 },
#       9
#      10 {
#      11
#      12     "coursename":"mlops",
#      13     "instrutorname":"sunnysavita",
#      14     "modeofsession":"english&hindi"
#      15 }
#      16
#      17     ]
#      18 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:948, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     946 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     947 blk.ops = list(gen())
# --> 948 blk.execute(write_concern, session, _Op.INSERT)
#     949 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:737, in _Bulk.execute(self, write_concern, session, operation)
#     735         return None
#     736 else:
# --> 737     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\bulk.py:594, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     583     self._execute_command(
#     584         generator,
#     585         write_concern,
#    (...)
#     590         full_result,
#     591     )
#     593 client = self.collection.database.client
# --> 594 _ = client._retryable_write(
#     595     self.is_retryable,
#     596     retryable_bulk,
#     597     session,
#     598     operation,
#     599     bulk=self,  # type: ignore[arg-type]
#     600     operation_id=op_id,
#     601 )
#     603 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     604     _raise_bulk_write_error(full_result)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1848, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1834 """Execute an operation with consecutive retries if possible
#    1835
#    1836 Returns func()'s return value on success. On error retries the same
#    (...)
#    1845 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1846 """
#    1847 with self._tmp_session(session) as s:
# -> 1848     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1734, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1729 # Ensure that the options supports retry_writes and there is a valid session not in
#    1730 # transaction, otherwise, we will not support retry behavior for this txn.
#    1731 retryable = bool(
#    1732     retryable and self.options.retry_writes and session and not session.in_transaction
#    1733 )
# -> 1734 return self._retry_internal(
#    1735     func=func,
#    1736     session=session,
#    1737     bulk=bulk,
#    1738     operation=operation,
#    1739     retryable=retryable,
#    1740     operation_id=operation_id,
#    1741 )
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1780, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1743 @_csot.apply
#    1744 def _retry_internal(
#    1745     self,
#    (...)
#    1754     operation_id: Optional[int] = None,
#    1755 ) -> T:
#    1756     """Internal retryable helper for all client transactions.
#    1757
#    1758     :param func: Callback function we want to retry
#    (...)
#    1767     :return: Output of the calling func()
#    1768     """
#    1769     return _ClientConnectionRetryable(
#    1770         mongo_client=self,
#    1771         func=func,
#    1772         bulk=bulk,
#    1773         operation=operation,
#    1774         is_read=is_read,
#    1775         session=session,
#    1776         read_pref=read_pref,
#    1777         address=address,
#    1778         retryable=retryable,
#    1779         operation_id=operation_id,
# -> 1780     ).run()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2367, in _ClientConnectionRetryable.run(self)
#    2365 self._check_last_error(check_csot=True)
#    2366 try:
# -> 2367     return self._read() if self._is_read else self._write()
#    2368 except ServerSelectionTimeoutError:
#    2369     # The application may think the write was never attempted
#    2370     # if we raise ServerSelectionTimeoutError on the retry
#    2371     # attempt. Raise the original exception instead.
#    2372     self._check_last_error()
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2471, in _ClientConnectionRetryable._write(self)
#    2469 is_mongos = False
#    2470 self._server = self._get_server()
# -> 2471 with self._client._checkout(self._server, self._session) as conn:
#    2472     max_wire_version = conn.max_wire_version
#    2473     sessions_supported = (
#    2474         self._session
#    2475         and self._server.description.retryable_writes_supported
#    2476         and conn.supports_sessions
#    2477     )
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1543, in MongoClient._checkout(self, server, session)
#    1541     yield session._pinned_connection
#    1542     return
# -> 1543 with server.checkout(handler=err_handler) as conn:
#    1544     # Pin this session to the selected server or connection.
#    1545     if (
#    1546         in_txn
#    1547         and session
#    (...)
#    1552         )
#    1553     ):
#    1554         session._pin(server, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1335, in Pool.checkout(self, handler)
#    1326 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1327     _debug_log(
#    1328         _CONNECTION_LOGGER,
#    1329         clientId=self._client_id,
#    (...)
#    1332         serverPort=self.address[1],
#    1333     )
# -> 1335 conn = self._get_conn(checkout_started_time, handler=handler)
#    1337 duration = time.monotonic() - checkout_started_time
#    1338 if self.enabled_for_cmap:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1494, in Pool._get_conn(self, checkout_started_time, handler)
#    1492 else:  # We need to create a new connection
#    1493     try:
# -> 1494         conn = self.connect(handler=handler)
#    1495     finally:
#    1496         with self._max_connecting_cond:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:1295, in Pool.connect(self, handler)
#    1292     if handler:
#    1293         handler.contribute_socket(conn, completed_handshake=False)
# -> 1295     conn.authenticate()
#    1296 except BaseException:
#    1297     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:648, in Connection.authenticate(self, reauthenticate)
#     645 if creds:
#     646     from pymongo.synchronous import auth
# --> 648     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     649 self.ready = True
#     650 duration = time.monotonic() - self.creation_time
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:452, in authenticate(credentials, conn, reauthenticate)
#     450     _authenticate_oidc(credentials, conn, reauthenticate)
#     451 else:
# --> 452     auth_func(credentials, conn)
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:356, in _authenticate_default(credentials, conn)
#     354         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     355     else:
# --> 356         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     357 else:
#     358     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\auth.py:134, in _authenticate_scram(credentials, conn, mechanism)
#     127 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     129 cmd = {
#     130     "saslContinue": 1,
#     131     "conversationId": res["conversationId"],
#     132     "payload": Binary(client_final),
#     133 }
# --> 134 res = conn.command(source, cmd)
#     136 parsed = _parse_scram_response(res["payload"])
#     137 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File c:\Users\Kartik\anaconda3\Lib\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
class mongodb_operation:

    def __init__(self,client_url: str, database_name: str, collection_name: str=None):
        self.client_url=client_url
        self.database_name=database_name
        self.collection_name=collection_name

    def create_client(self):
        client=MongoClient(self.client_url)
        return client


    def create_database(self):
        client=self.create_client()
        database=client[self.database_name]
        return database
        
    def create_collection(self,collection=None):
        database=self.create_database()
        collection=database[collection]
        return collection

    def insert_record(self,record:dict,collection_name:str):
        if type(record)==list:
            for data in record:
                if type(data)!= dict:
                    raise TypeError("record must be in the dict")
            collection=self.create_collection(collection_name)
            collection.insert_many(record)
        elif type(record)==dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)

    def bulk_insert(self,datafile:str,collection_name:str=None):
        self.path=datafile

        if self.path.endswith('.csv'):
            data=pd.read_csv(self.path,encoding='utf-8')

        elif self.path.endswith('.xlsx'):
            data=pd.read_excel(self.path,encoding='utf-8')
            
        datajson=json.loads(data.to_json(orient='record'))
        collection=self.create_collection()
        collection.insert_many(datajson)

# %%
#call the mongodb connection 
client_url =  "mongodb+srv://snshrivas:Snshrivas@cluster0.u46c4.mongodb.net/?retryWrites=true&w=majority"   # I have created a demo connection for you to understand. You can use your own.
database = "mynewdatabase"
collection_name = "myoldcolumn"

# %%
mongo=mongodb_operation(client_url,database,collection_name)

# %%
mongo.insert_record({"name":"sunny","designation":"data scientist","salary":"10k"},collection_name)

# %%
mongo.insert_record([{"name":"sunny","designation":"data scientist","salary":"10k"},
{"name":"sudhanshu","designation":"sr. data scientist","salary":"150k"},
{"name":"krish","designation":"lead data scientist","salary":"70k"}
],collection_name)
